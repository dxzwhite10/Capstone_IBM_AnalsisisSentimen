# %% [markdown]
# ## LIBRARY

# %%
import pandas as pd
pd.options.mode.chained_assignment = None
import numpy as np
seed = 0
np.random.seed(seed)
import seaborn as sns
import datetime as dt
import re
import string
import nltk
import csv
from sklearn.metrics import accuracy_score
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from google_play_scraper import app, reviews, Sort, reviews_all
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# ## Scraping Dataset

# %%
scrapreview = reviews_all(
    'com.supercell.brawlstars',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    sleep_milliseconds=1500,
    count=10000
)

# %%
with open('Brawl_Stars.csv', 'w', newline='', encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(['review'])
    for review in scrapreview:
        writer.writerow([review['content']])

# %% [markdown]
# ## Loading Dataset

# %%
app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df.shape
app_reviews_df.head(10)
# Out:
#                                reviewId         userName  \
# 0  c53e3a06-a590-4d60-ab85-8fc51cca9fe2  Pengguna Google
# 1  0018ecaf-a3ee-404e-8e39-957539192135  Pengguna Google
# 2  50409ff5-eb2d-401b-ad9f-bb0890b71be3  Pengguna Google
# 3  beb6920b-d524-4fe2-be48-f5117c74c033  Pengguna Google
# 4  35c36fc3-c71c-4893-aec4-75dbb6c29fdf  Pengguna Google
# 5  eb6e65db-d209-402c-b25e-4f66a94fb904  Pengguna Google
# 6  31485054-da5f-4ff8-a405-96641407981f  Pengguna Google
# 7  4a7b399b-0037-4770-968e-86305e9b007d  Pengguna Google
# 8  8312fef8-4112-489d-b9bb-76b8e5fe25a2  Pengguna Google
# 9  635cf016-ad1a-4795-a852-78f6a419c7c4  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
# 5  https://play-lh.googleusercontent.com/EGemoI2N...
# 6  https://play-lh.googleusercontent.com/EGemoI2N...
# 7  https://play-lh.googleusercontent.com/EGemoI2N...
# 8  https://play-lh.googleusercontent.com/EGemoI2N...
# 9  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Matchmaking game ini itu betul-betul jelek ban...      1              8
# 1  Keluh kesah main game ini selalu aja bertambah...      1            150
# 2  bagus tapi kadang suka lama (loading) kalau ud...      2              4
# 3  Game ini tolong kasih fitur chat lahhh biar bi...      1              4
# 4  gamenya bagus tapi pas mau buka karakter kenap...      5             55
# 5  guys aku KEMBALI!!!!!!! Eventnya makin seru ga...      5              1
# 6  masalah jaringan terus, udah ganti data yang j...      1              4
# 7  game nya suka tiba ngelag padahal sinyal bagus...      3              1
# 8  saya tidak menyukai game ini di bagian mendapa...      1              8
# 9  jangan bilang nih game bisa cheat bikin musuh ...      2              1
#
#   reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0               63.342 2025-10-11 02:32:20         None      None     63.342
# 1               63.322 2025-09-22 16:31:45         None      None     63.322
# 2               63.342 2025-09-30 11:53:29         None      None     63.342
# 3               63.342 2025-10-07 08:52:22         None      None     63.342
# 4               63.342 2025-10-03 12:13:07         None      None     63.342
# 5               63.342 2025-10-09 12:11:28         None      None     63.342
# 6               63.342 2025-10-12 08:09:15         None      None     63.342
# 7               63.342 2025-10-12 08:16:16         None      None     63.342
# 8               63.342 2025-10-05 08:25:40         None      None     63.342
# 9               63.342 2025-10-06 11:51:10         None      None     63.342
